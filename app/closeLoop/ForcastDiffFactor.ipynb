# %%
from hydroDL import pathSMAP, master, utils
from hydroDL.master import default
from hydroDL.post import plot, stat
import os
import matplotlib.pyplot as plt
import numpy as np
import torch
import pandas as pd

doLst = list()
# doLst.append('train')
doLst.append('test')
doLst.append('post')
saveDir = os.path.join(pathSMAP['dirResult'], 'DA')

# test
if 'test' in doLst:
    torch.cuda.set_device(2)

    subset = 'CONUSv2f1'
    tRange = [20150402, 20180401]
    yrStrLst = ['2015', '2016', '2017']
    yfLst = list()
    ypLst = list()
    for yrStr in yrStrLst:
        out = os.path.join(pathSMAP['Out_L3_NA'], 'DA', 'CONUSv2f1_DA' + yrStr)
        df, yf, obs = master.test(
            out, tRange=tRange, subset=subset, batchSize=100)
        out = os.path.join(pathSMAP['Out_L3_NA'], 'DA',
                           'CONUSv2f1_LSTM' + yrStr)
        df, yp, obs = master.test(out, tRange=tRange, subset=subset)
        yf = yf.squeeze()
        yp = yp.squeeze()
        yfLst.append(yf)
        ypLst.append(yp)
    obs = obs.squeeze()
# Out:
# loading package hydroDL
# read master file /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_DA2015/master.json
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/APCP_FORA.csv 0.12326383590698242
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/APCP_FORA.csv 0.1268620491027832
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/APCP_FORA.csv 0.12330198287963867
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DLWRF_FORA.csv 0.1597137451171875
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DLWRF_FORA.csv 0.14775323867797852
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DLWRF_FORA.csv 0.14889812469482422
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DSWRF_FORA.csv 0.15685248374938965
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DSWRF_FORA.csv 0.14547991752624512
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DSWRF_FORA.csv 0.14789366722106934
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/TMP_2_FORA.csv 0.1562185287475586
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/TMP_2_FORA.csv 0.14280939102172852
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/TMP_2_FORA.csv 0.14328956604003906
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SPFH_2_FORA.csv 0.19937443733215332
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SPFH_2_FORA.csv 0.1547408103942871
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SPFH_2_FORA.csv 0.14799928665161133
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/VGRD_10_FORA.csv 0.1628570556640625
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/VGRD_10_FORA.csv 0.14953994750976562
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/VGRD_10_FORA.csv 0.14955353736877441
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/UGRD_10_FORA.csv 0.17262887954711914
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/UGRD_10_FORA.csv 0.15146732330322266
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/UGRD_10_FORA.csv 0.14932036399841309
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.1397864818572998
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.13576841354370117
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11817789077758789
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.15541911125183105
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.1484546661376953
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.12229394912719727
# /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_DA2015/CONUSv2f1_20150402_20180401.csv
# Loaded previous results
# read master file /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_LSTM2015/master.json
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/APCP_FORA.csv 0.1287240982055664
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/APCP_FORA.csv 0.12022876739501953
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/APCP_FORA.csv 0.11456680297851562
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DLWRF_FORA.csv 0.14371800422668457
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DLWRF_FORA.csv 0.14175772666931152
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DLWRF_FORA.csv 0.14891433715820312
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DSWRF_FORA.csv 0.14696884155273438
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DSWRF_FORA.csv 0.14320039749145508
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DSWRF_FORA.csv 0.14443707466125488
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/TMP_2_FORA.csv 0.1684865951538086
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/TMP_2_FORA.csv 0.16248440742492676
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/TMP_2_FORA.csv 0.14496970176696777
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SPFH_2_FORA.csv 0.15671586990356445
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SPFH_2_FORA.csv 0.14818692207336426
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SPFH_2_FORA.csv 0.1478886604309082
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/VGRD_10_FORA.csv 0.14536070823669434
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/VGRD_10_FORA.csv 0.14218807220458984
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/VGRD_10_FORA.csv 0.1420605182647705
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/UGRD_10_FORA.csv 0.1456584930419922
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/UGRD_10_FORA.csv 0.14234328269958496
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/UGRD_10_FORA.csv 0.1426534652709961
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.12408041954040527
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.1414051055908203
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.15483760833740234
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.1307821273803711
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.126295804977417
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11347079277038574
# /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_LSTM2015/CONUSv2f1_20150402_20180401.csv
# Loaded previous results
# read master file /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_DA2016/master.json
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/APCP_FORA.csv 0.12656807899475098
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/APCP_FORA.csv 0.11913347244262695
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/APCP_FORA.csv 0.12312769889831543
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DLWRF_FORA.csv 0.14512014389038086
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DLWRF_FORA.csv 0.13885283470153809
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DLWRF_FORA.csv 0.1372206211090088
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DSWRF_FORA.csv 0.1425008773803711
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DSWRF_FORA.csv 0.13825345039367676
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DSWRF_FORA.csv 0.1690218448638916
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/TMP_2_FORA.csv 0.14353418350219727
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/TMP_2_FORA.csv 0.13634133338928223
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/TMP_2_FORA.csv 0.14232444763183594
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SPFH_2_FORA.csv 0.15346169471740723
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SPFH_2_FORA.csv 0.1463606357574463
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SPFH_2_FORA.csv 0.14627671241760254
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/VGRD_10_FORA.csv 0.14569377899169922
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/VGRD_10_FORA.csv 0.1412811279296875
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/VGRD_10_FORA.csv 0.13949322700500488
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/UGRD_10_FORA.csv 0.1497962474822998
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/UGRD_10_FORA.csv 0.1606895923614502
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/UGRD_10_FORA.csv 0.14257025718688965
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.14417791366577148
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.14078235626220703
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11757230758666992
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.12543034553527832
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.11867690086364746
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11446356773376465
# /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_DA2016/CONUSv2f1_20150402_20180401.csv
# Loaded previous results
# read master file /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_LSTM2016/master.json
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/APCP_FORA.csv 0.12481212615966797
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/APCP_FORA.csv 0.12082290649414062
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/APCP_FORA.csv 0.11650896072387695
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DLWRF_FORA.csv 0.14138340950012207
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DLWRF_FORA.csv 0.14423775672912598
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DLWRF_FORA.csv 0.14470839500427246
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DSWRF_FORA.csv 0.17395305633544922
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DSWRF_FORA.csv 0.16977906227111816
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DSWRF_FORA.csv 0.1459207534790039
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/TMP_2_FORA.csv 0.14389634132385254
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/TMP_2_FORA.csv 0.14523935317993164
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/TMP_2_FORA.csv 0.14458012580871582
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SPFH_2_FORA.csv 0.15462017059326172
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SPFH_2_FORA.csv 0.15026235580444336
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SPFH_2_FORA.csv 0.15253591537475586
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/VGRD_10_FORA.csv 0.14473199844360352
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/VGRD_10_FORA.csv 0.13889241218566895
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/VGRD_10_FORA.csv 0.14042878150939941
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/UGRD_10_FORA.csv 0.14559674263000488
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/UGRD_10_FORA.csv 0.14082789421081543
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/UGRD_10_FORA.csv 0.14523720741271973
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.12158727645874023
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.12487149238586426
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11071133613586426
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.12725114822387695
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.12490034103393555
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11195540428161621
# /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_LSTM2016/CONUSv2f1_20150402_20180401.csv
# Loaded previous results
# read master file /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_DA2017/master.json
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/APCP_FORA.csv 0.12566089630126953
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/APCP_FORA.csv 0.12159919738769531
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/APCP_FORA.csv 0.11686539649963379
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DLWRF_FORA.csv 0.14027118682861328
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DLWRF_FORA.csv 0.13619303703308105
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DLWRF_FORA.csv 0.1392662525177002
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DSWRF_FORA.csv 0.15268349647521973
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DSWRF_FORA.csv 0.13724136352539062
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DSWRF_FORA.csv 0.1326770782470703
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/TMP_2_FORA.csv 0.1371595859527588
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/TMP_2_FORA.csv 0.13495707511901855
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/TMP_2_FORA.csv 0.1326453685760498
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SPFH_2_FORA.csv 0.14795780181884766
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SPFH_2_FORA.csv 0.14397001266479492
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SPFH_2_FORA.csv 0.14259028434753418
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/VGRD_10_FORA.csv 0.14094233512878418
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/VGRD_10_FORA.csv 0.13692116737365723
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/VGRD_10_FORA.csv 0.14217710494995117
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/UGRD_10_FORA.csv 0.1415421962738037
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/UGRD_10_FORA.csv 0.13937616348266602
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/UGRD_10_FORA.csv 0.13944387435913086
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.1184854507446289
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.11383938789367676
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.10937285423278809
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.12335062026977539
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.1237177848815918
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11519026756286621
# /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_DA2017/CONUSv2f1_20150402_20180401.csv
# Loaded previous results
# read master file /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_LSTM2017/master.json
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/APCP_FORA.csv 0.14356350898742676
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/APCP_FORA.csv 0.1276404857635498
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/APCP_FORA.csv 0.12353062629699707
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DLWRF_FORA.csv 0.14599609375
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DLWRF_FORA.csv 0.14164137840270996
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DLWRF_FORA.csv 0.14357566833496094
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/DSWRF_FORA.csv 0.14566850662231445
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/DSWRF_FORA.csv 0.14175772666931152
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/DSWRF_FORA.csv 0.13780736923217773
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/TMP_2_FORA.csv 0.14326882362365723
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/TMP_2_FORA.csv 0.14504766464233398
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/TMP_2_FORA.csv 0.13698101043701172
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SPFH_2_FORA.csv 0.15456151962280273
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SPFH_2_FORA.csv 0.1424856185913086
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SPFH_2_FORA.csv 0.15194106101989746
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/VGRD_10_FORA.csv 0.14893293380737305
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/VGRD_10_FORA.csv 0.13826251029968262
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/VGRD_10_FORA.csv 0.13935565948486328
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/UGRD_10_FORA.csv 0.14900803565979004
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/UGRD_10_FORA.csv 0.14066648483276367
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/UGRD_10_FORA.csv 0.14390873908996582
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.1242222785949707
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.12184500694274902
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.1133887767791748
# /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/Subset/CONUSv2f1.csv
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/SMAP_AM.csv 0.12665319442749023
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/SMAP_AM.csv 0.1216285228729248
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/SMAP_AM.csv 0.11270713806152344
# /mnt/sdb/rnnSMAP/Model_SMAPgrid/L3_NA/DA/CONUSv2f1_LSTM2017/CONUSv2f1_20150402_20180401.csv
# Loaded previous results

# %%
# figure out how many days observation lead
maskObs = 1 * ~np.isnan(obs.squeeze())
maskDay = np.zeros(maskObs.shape).astype(int)
ngrid, nt = maskObs.shape
for j in range(ngrid):
    temp = 0
    for i in range(nt):
        maskDay[j, i] = temp
        if maskObs[j, i] == 1:
            temp = 1
        else:
            if temp != 0:
                temp = temp + 1
ind = np.random.randint(0, ngrid)
maskObsDay = maskObs * maskDay
unique, counts = np.unique(maskObsDay, return_counts=True)
maskF = (maskDay >= 1) & (maskDay <= 3)
statPLst=list()
statFLst=list()
for k in range(3):
    statP = stat.statError(utils.fillNan(ypLst[k], maskF), utils.fillNan(obs, maskF))
    statF = stat.statError(utils.fillNan(yfLst[k], maskF), utils.fillNan(obs, maskF))
    statPLst.append(statP)
    statFLst.append(statF)
# Out:
# /home/kxf227/anaconda3/envs/pytorch/lib/python3.6/site-packages/scipy/stats/stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
# plot map and time series
# %matplotlib notebook
import importlib
importlib.reload(plot)
cropFile = r'/mnt/sdb/Data/Crop/cropRate_CONUSv2f1.csv'
cropRate = pd.read_csv(cropFile, dtype=np.float, header=None).values
# croprate - 0 corn, 4 soybean, 22 spring wheat, 23 winter wheat
dataGrid = [statPLst[0]['RMSE'] / statFLst[0]['RMSE'], 
            statPLst[1]['RMSE'] / statFLst[1]['RMSE'],
            statPLst[2]['RMSE'] / statFLst[2]['RMSE']]
prcp = df.getDataTs('APCP_FORA').squeeze()
dataTs = [[obs, ypLst[0], yfLst[0]], [obs, ypLst[1], yfLst[1]],
          [obs, ypLst[2], yfLst[2]], [prcp]]
crd = df.getGeo()
t = df.getT()
mapNameLst = ['dRMSE 2015', 'dRMSE 2016','dRMSE 2017']
tsNameLst = ['obs', 'prj', 'fore']
tBar = [utils.time.t2dt(20160401),utils.time.t2dt(20170401)]
#plt.tight_layout()
plot.plotTsMap(
    dataGrid,
    dataTs,
    lat=crd[0],
    lon=crd[1],
    t=t,
    mapNameLst=mapNameLst,
    isGrid=True,
    multiTS=True,
    linewidth=1,
    figsize=(10,10),
    tBar=tBar)
# Out:
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2015/APCP_FORA.csv 0.1514291763305664
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2016/APCP_FORA.csv 0.13150811195373535
# read /mnt/sdc/rnnSMAP/Database_SMAPgrid/Daily_L3_NA/CONUSv2f1/2017/APCP_FORA.csv 0.1273941993713379
# <img src="data:image/png;base64,..." width="1000">
# /home/kxf227/anaconda3/envs/pytorch/lib/python3.6/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# see result for different seasons
tRangeLst = [[20180101, 20180201], [20180201, 20180301], [20180301, 20180401],
             [20160401, 20160501], [20160501, 20160601], [20160601, 20160701],
             [20160701, 20160801], [20160801, 20160901], [20160901, 20161001],
             [20161001, 20161101], [20161101, 20161201], [20161201, 20170101],
             [20170101, 20170201], [20170201, 20170301], [20170301, 20170401],
             [20170401, 20170501], [20170501, 20170601], [20170601, 20170701],
             [20170701, 20170801], [20170801, 20170901], [20170901, 20171001],
             [20171001, 20171101], [20171101, 20171201], [20171201, 20180101]]
tAllR = [20150402, 20180401]
tAllA = utils.time.tRange2Array(tAllR)
statPLst = list()
statFLst = list()
for k in range(12):
    tRLst = [tRangeLst[k], tRangeLst[k + 12]]
    temp = list()
    for tR in tRLst:
        tA = utils.time.tRange2Array(tR)
        ind0 = np.array(range(nt))
        ind1, ind2 = utils.time.intersect(tAllA, tA)
        temp.append(ind1)
    indT = np.concatenate(temp)
    yfTemp = utils.fillNan(yf, maskF)[:, indT]
    ypTemp = utils.fillNan(yp, maskF)[:, indT]
    obsTemp = utils.fillNan(obs, maskF)[:, indT]
    statPLst.append(stat.statError(ypTemp, obsTemp))
    statFLst.append(stat.statError(yfTemp, obsTemp))

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 14})
matplotlib.rcParams.update({'lines.linewidth': 2})
matplotlib.rcParams.update({'lines.markersize': 6})

labCrop = ['Corn', 'Spring wheat', 'Winter wheat']
indCrop=[0,22,23]
cropFile = r'/mnt/sdb/Data/Crop/cropRate_CONUSv2f1.csv'
cropRate = pd.read_csv(cropFile, dtype=np.float, header=None).values
key = 'RMSE'
[lat, lon] = df.getGeo()
fig, axes = plt.subplots(1, 3, figsize=[12, 5])
for k in range(3):
    grid, uy, ux = utils.grid.array2grid(cropRate[:, indCrop[k]], lat=lat, lon=lon)
    plot.plotMap(grid, ax=axes[k], lat=uy, lon=ux,title=labCrop[k]+' percentage')
    plt.tight_layout()
    fig.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 14})
matplotlib.rcParams.update({'lines.linewidth': 2})
matplotlib.rcParams.update({'lines.markersize': 6})
indLst = [cropRate[:, 0] > 30, cropRate[:, 22] > 5, cropRate[:, 23] > 10]
labMonth = [
    'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Agu', 'Sep', 'Oct',
    'Nov', 'Dec'
]
labCrop = ['Corn', 'Spring wheat', 'Winter wheat']
cLst='rgb'
dataBox = list()
for iC in range(len(indLst)):
    dataBox = list()
    for k in range(12):
        data = statPLst[k]['RMSE'][indLst[iC]] - statFLst[k]['RMSE'][
            indLst[iC]]
        if len(data[~np.isnan(data)]) < 20:
            data = []
        dataBox.append(data)
    fig = plot.plotBoxFig(
        dataBox,
        label1=labMonth,
        label2=[labCrop[iC]],
        sharey=True,
        figsize=[8, 3],
        colorLst=cLst[iC])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.ylim(-0.02, 0.04)
    fig.show()
# Out:
# <div id='0f347be4-4b67-4e0b-9c32-d8d6496950c7'></div>
# <div id='fa4798d3-5eae-43cf-a253-323191cff97d'></div>
